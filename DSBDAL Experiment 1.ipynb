# %%
#Data Wrangling 1
#import libraries

import pandas as pd 
import matplotlib.pylab as plt 
import numpy as np

# %%
#import dataset
df=pd.read_csv("D:\Sem 6\DSBDA Pract\Iris.csv")

# %%
#Show the content of dataset from top
df.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
#Check the content of dataset from bottom
df.tail(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
#for no of columns,column label,column datatype,range index,no of cells in each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#Read the Data Column wise.

df['SepalLengthCm']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
#descriptive statistics as percentile,mean,standard deviation
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#Sort values by column name.
df.sort_values(by="SepalWidthCm")
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 60    61            5.0           2.0            3.5           1.0
# 62    63            6.0           2.2            4.0           1.0
# 119  120            6.0           2.2            5.0           1.5
# 68    69            6.2           2.2            4.5           1.5
# 41    42            4.5           2.3            1.3           0.3
# ..   ...            ...           ...            ...           ...
# 16    17            5.4           3.9            1.3           0.4
# 14    15            5.8           4.0            1.2           0.2
# 32    33            5.2           4.1            1.5           0.1
# 33    34            5.5           4.2            1.4           0.2
# 15    16            5.7           4.4            1.5           0.4
#
#              Species
# 60   Iris-versicolor
# 62   Iris-versicolor
# 119   Iris-virginica
# 68   Iris-versicolor
# 41       Iris-setosa
# ..               ...
# ...

# %%
#Purely integer-location based indexing for selection byposition.
df.iloc[63]
# Out:
# Id                            64
# SepalLengthCm                6.1
# SepalWidthCm                 2.9
# PetalLengthCm                4.7
# PetalWidthCm                 1.4
# Species          Iris-versicolor
# Name: 63, dtype: object

# %%
#Selecting which slices the rows.
df[0:3]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %%
#slice the data
df.iloc[3:5, 0:2]
# Out:
#    Id  SepalLengthCm
# 3   4            4.6
# 4   5            5.0

# %%
#lists of integer position locations, similar to the NumPy/Python style
df.iloc[[1, 2,4], [0, 2]]
# Out:
#    Id  SepalWidthCm
# 1   2           3.0
# 2   3           3.2
# 4   5           3.6

# %%
# Checking of missing Data
                                                
df.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
#sum() will get the

df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
#is there any missing values across each column

df.notnull().any()
# Out:
# Id               True
# SepalLengthCm    True
# SepalWidthCm     True
# PetalLengthCm    True
# PetalWidthCm     True
# Species          True
# dtype: bool

# %%
 df.isnull().any()
# Out:
# Id               False
# SepalLengthCm    False
# SepalWidthCm     False
# PetalLengthCm    False
# PetalWidthCm     False
# Species          False
# dtype: bool

# %%
df.notnull().sum()

# %%
#calculate the mean value for SepalLength 

avg_len=df["SepalLengthCm"].astype("float").mean(axis=0)

print("Average of SepalLengthCm ",avg_len)

df["SepalLengthCm"].replace(np.nan,avg_len,inplace=True)

# %%
 df.isnull().any()

# %%
from sklearn import preprocessing

# %%
df['SeplLengthCm']=df['SepalLengthCm'].astype('float')
print(df.dtypes)
# Out:
# Id                       int64
# SepalLengthCm            int32
# SepalWidthCm           float64
# PetalLengthCm            int32
# PetalWidthCm           float64
# Species                 object
# SepalLengthLengthCm      int32
# SeplLength             float64
# SeplLengthCm           float64
# dtype: object

# %%
x=df[['PetalWidthCm']].values.astype(float)
min_max_scaler=preprocessing.MinMaxScaler()
x_scaled=min_max_scaler.fit_transform(x)
df_normalized=pd.DataFrame(x_scaled)
print(df_normalized.head(10))
# Out:
#           0
# 0  0.041667
# 1  0.041667
# 2  0.041667
# 3  0.041667
# 4  0.041667
# 5  0.125000
# 6  0.083333
# 7  0.041667
# 8  0.041667
# 9  0.000000

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
label_encoder=preprocessing.LabelEncoder()
df['Species']=label_encoder.fit_transform(df['Species'])
print(df)
print(df['Species'].unique())
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species  \
# 0      1              1           3.5              1           0.2        0
# 1      2              1           3.0              1           0.2        0
# 2      3              1           3.2              1           0.2        0
# 3      4              1           3.1              1           0.2        0
# 4      5              1           3.6              1           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146              5           3.0              5           2.3        2
# 146  147              5           2.5              5           1.9        2
# 147  148              5           3.0              5           2.0        2
# 148  149              5           3.4              5           2.3        2
# 149  150              5           3.0              5           1.8        2
#
#      SepalLengthLengthCm  SeplLength  SeplLengthCm
# ...

# %%
features_df=df.drop(columns=['Species'])
enc=preprocessing.OneHotEncoder()
enc_df=pd.DataFrame(enc.fit_transform(df[['Species']]))
df_encode=features_df.join(enc_df)
df_encode.rename(columns={0:'Iris-virginica'},inplace=True)
print(df_encode.tail(40))
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 110  111              5           3.2              5           2.0
# 111  112              5           2.7              5           1.9
# 112  113              5           3.0              5           2.1
# 113  114              5           2.5              5           2.0
# 114  115              5           2.8              5           2.4
# 115  116              5           3.2              5           2.3
# 116  117              5           3.0              5           1.8
# 117  118              6           3.8              6           2.2
# 118  119              6           2.6              6           2.3
# 119  120              5           2.2              5           1.5
# 120  121              5           3.2              5           2.3
# 121  122              4           2.8              4           2.0
# 122  123              6           2.8              6           2.0
# ...
